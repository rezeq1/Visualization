# %% [markdown]
# # Exercise 1

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")

plt.title('Company profit per month')
plt.ylabel('Profit in dollar')
plt.xlabel('Month number')

plt.plot(df ['month_number'].tolist(), df ['total_profit'].tolist())
plt.yticks([x*100000 for x in range(1,6)])
plt.xticks(df ['month_number'].tolist())

plt.show()

# %% [markdown]
# # Exercise 2

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")

plt.title('Company profit per month')
plt.ylabel('Profit in dollar')
plt.xlabel('Month number')

plt.plot(df ['month_number'].tolist(), df ['total_profit'].tolist(), label = 'Profit data of last year',linewidth=4, 
      linestyle='--', markerfacecolor='k',color='red', marker='o')
plt.yticks([x*100000 for x in range(1,6)])
plt.xticks(df ['month_number'].tolist())      
      

plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# # Exercise 3

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")
month_values  = df ['month_number'].tolist()
plt.title('Sales data')
plt.ylabel('Sales units in number')
plt.xlabel('Month Number')


plt.plot(month_values, df ['facecream'].tolist(),   label = 'Face cream Sales Data', linewidth=4, marker='o')
plt.plot(month_values, df ['facewash'].tolist(),   label = 'Face Wash Sales Data',linewidth=4, marker='o')
plt.plot(month_values, df ['toothpaste'].tolist(), label = 'ToothPaste Sales Data',linewidth=4, marker='o')
plt.plot(month_values, df ['bathingsoap'].tolist(), label = 'ToothPaste Sales Data',linewidth=4, marker='o')
plt.plot(month_values, df ['shampoo'].tolist(), label = 'ToothPaste Sales Data',linewidth=4, marker='o')
plt.plot(month_values, df ['moisturizer'].tolist(), label = 'ToothPaste Sales Data',linewidth=4, marker='o')

plt.legend(loc='upper left')
plt.yticks([1000]+[1000*x for x in range(2,19,2)])
plt.xticks(month_values)


plt.show()

# %% [markdown]
# # Exercise 4

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")

plt.title(' Tooth paste Sales data')
plt.ylabel('Number of units Sold')
plt.xlabel('Month Number')
plt.xticks(df ['month_number'].tolist())

plt.scatter(df ['month_number'].tolist(),df ['toothpaste'].tolist(), label = 'Tooth paste Sales data')

plt.legend(loc='upper left')
plt.grid(linestyle="--")

plt.show()

# %% [markdown]
# # Exercise 5

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")
plt.title('Facewash and facecream sales data')
plt.ylabel('Sales units in number')
plt.xlabel('Month Number')
plt.xticks(df ['month_number'].tolist())


plt.bar(df ['month_number'].tolist(), df ['facecream'].tolist(),width=-0.3, label = 'Face Cream sales data', align='edge')
plt.bar(df ['month_number'].tolist(), df ['facewash'].tolist(), width= 0.3, label = 'Face Wash sales data', align='edge')

plt.legend(loc='upper left')
plt.grid(linestyle="--")

plt.show()

# %% [markdown]
# # Exercise 6

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")

plt.title('bathingsoap sales data')
plt.ylabel('Sales units in number')
plt.xlabel('Month Number')
plt.xticks(df ['month_number'].tolist())

plt.bar(df ['month_number'].tolist(), df ['bathingsoap'].tolist())

plt.grid( linestyle="--")

plt.show()

# %% [markdown]
# # Exercise 7

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")

plt.title('Profit data')
plt.ylabel('Actual Profit in dollar')
plt.xlabel('profit range in dollar')
plt.xticks(profit_range)


plt.hist(df ['total_profit'].tolist(),[x for x in range(150000,350000+25000,25000)] , label = 'Profit data')

plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# # Exercise 8

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")
plt.title('Sales data')
plt.axis("equal")

values   = [sum(df['facecream'].tolist()),sum(df['facewash'].tolist()),sum(df['toothpaste'].tolist()), 
         sum(df['bathingsoap'].tolist()),sum(df['shampoo'].tolist()),sum(df['moisturizer'].tolist())]

plt.pie(values, labels=['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer'], autopct='%.1f%%')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# # Exercise 9

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")


plots = plt.subplots(2, sharex=True)[1]
plots[0].plot(df ['month_number'].tolist(),df['bathingsoap'].tolist(), color='black', linewidth=4, marker='o')
plots[1].plot(df ['month_number'].tolist(),df['facewash'].tolist(), color='red', linewidth=4, marker='o')

plots[0].set_title('Sales data of  a Bathingsoap')
plots[1].set_title('Sales data of  a facewash')


plt.show()

# %% [markdown]
# # Exercise 10

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")

plt.title('Alll product sales data using stack plot')
plt.ylabel('Sales unints in Number')
plt.xlabel('Month Number')


values1=df['month_number'].tolist()
values2=df['facecream'].tolist()
values3=df['facewash'].tolist()
values4=df['toothpaste'].tolist()
values5=df['bathingsoap'].tolist()
values6=df['shampoo'].tolist()
values7=df['moisturizer'].tolist()

colors_values=['magenta','cyan','red','black','green','yellow']
labels_values=['face Cream','Face wash','Tooth paste','Bathing soap','Shampoo','Moisturizer']



plt.stackplot(values1, values2, values3, values4,values5, values6, values7,colors=colors_values) 
              
plt.legend(labels_values,loc='upper left')

plt.show()

# %% [markdown]
# # Exercise 11

# %%
from bokeh.plotting import figure, output_file, show,save
import pandas as pd

df = pd.read_csv('us-marriages-divorces-1867-2014.csv')

plot = figure(title='marriages and divorces per capita in the U.S. between 1867 and 2014', x_axis_label='Year',
              y_axis_label='capita')
plot.line(df['Year'].tolist(), df['Marriages_per_1000'],legend='Marriages')
plot.line(df['Year'].tolist(), df['Divorces_per_1000'],line_color='red', legend='Divorces')
show(plot)

# %% [markdown]
# # Exercise 12

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

style.use("ggplot")

df = pd.read_csv('us-marriages-divorces-1867-2014.csv')

plt.title(' marriages and divorces per capita in the U.S. between 1867 and 2014')
plt.ylabel('capita')
plt.xlabel('Year')

plt.plot(df['Year'].tolist(),df['Marriages_per_1000'],label = 'Marriages')
plt.plot(df['Year'].tolist(),df['Divorces_per_1000'],label = 'Divorces')

plt.legend()

plt.show()

# %% [markdown]
# # Exercise 13

# %%
import numpy as np
import seaborn as sns
import pandas as pd

df= pd.read_csv('us-marriages-divorces-1867-2014.csv')
df= df[df['Year'].apply(lambda year: year in [1900, 1950, 2000])]
years = df['Year'].tolist()
marriages= df['Marriages_per_1000'].tolist()
divorces= df['Divorces_per_1000'].tolist()
sns.set(style="whitegrid")
val=[]
for i in range(0,len(years)):
    val.append(df.iloc[i]["Marriages_per_1000"])
    val.append(df.iloc[i]['Divorces_per_1000'])
data=pd.DataFrame({"Year":years*2,"Type":["Marriages",'Divorces']*len(years),"Per 1000 person":val})
title_='number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000'
ax = sns.barplot(x="Year", y="Per 1000 person", hue="Type", data=data)

# %% [markdown]
# # Exercise 14

# %%
import pandas as pd
import seaborn as sns
df= pd.read_csv('actor_kill_counts.csv')
horizontal_bar = sns.barplot(x='Count', y='Actor', data=df)
horizontal_bar

# %% [markdown]
# # Exercise 15

# %%
from math import pi
import pandas as pd
from bokeh.plotting import figure,show
from bokeh.transform import cumsum
from bokeh.models import LabelSet, ColumnDataSource

df = pd.read_csv('roman-emperor-reigns.csv')
assassinated_emperors = df[
    df['Cause_of_Death'].apply(lambda x: 'assassinated' in x.lower())]

number_assassinated = len(assassinated_emperors)
other_deaths = len(df) - number_assassinated


x = {'Assassinated': number_assassinated,'OtherDeaths': other_deaths}
tit='The fraction of all Roman Emperors that were assassinated'

data = pd.Series(x).reset_index(name='value').rename(columns={'index':'Deaths'})
data['angle'] = data['value']/data['value'].sum() * 2*pi
data['color'] = ['#3182bd','#fd8d3c']

p = figure(plot_height=350, title=tit, toolbar_location=None,
           tools="hover", tooltips="@Deaths: @value", x_range=(-0.5, 1.0))

p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend='Deaths', source=data)

sum=data["value"][0]+data["value"][1]
d=[data["value"][0]/sum*100,data["value"][1]/sum*100]
data["value"]=['%.1f'%d[0]+'%','%.1f'%d[1]+'%']
data["value"] = data['value'].astype(str)
data["value"] = data["value"].str.pad(35, side = "left")
source = ColumnDataSource(data)

labels = LabelSet(x=0, y=1, text='value',
        angle=cumsum('angle', include_zero=True), source=source, render_mode='canvas')

p.add_layout(labels)

p.axis.axis_label=None
p.axis.visible=False
p.grid.grid_line_color = None

show(p)

# %% [markdown]
# # Exercise 16

# %%
import pandas as pd
import seaborn as sns
from matplotlib import style

style.use("ggplot")

df = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
sns.set_style("dark")
hue1='Computer Science Doctorates Awarded (US)'
sns.scatterplot(x='Year', y='Total Arcade Revenue (billions)', hue=hue1, data=df)

# %% [markdown]
# # Exercise 17

# %%
import pandas as pd
import matplotlib.pyplot as plt  
from matplotlib import style

style.use("fivethirtyeight")
df = pd.read_csv('us-marriages-divorces-1867-2014.csv')
plt.plot(df['Year'].tolist(),df['Marriages_per_1000'].tolist())
plt.plot(df['Year'].tolist(),df['Divorces_per_1000'].tolist())

plt.show()

# %% [markdown]
# # Exercise 18

# %%
MyStyle = '''
axes.prop_cycle : cycler('color', ['1f77b4','ff7f0e'])
lines.linewidth : 2.5
ytick.labelsize : 12
xtick.labelsize : 12
'''
write_file=open('CoustomStyle.mplstyle', 'w')
write_file.write(MyStyle)
write_file.close()

# %% [markdown]
# # Exercise 19

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("CoustomStyle.mplstyle")

df = pd.read_csv("company_sales_data.csv")
plt.title('Sales data')
plt.axis("equal")

values   = [sum(df['facecream'].tolist()),sum(df['facewash'].tolist()),sum(df['toothpaste'].tolist()), 
         sum(df['bathingsoap'].tolist()),sum(df['shampoo'].tolist()),sum(df['moisturizer'].tolist())]

plt.pie(values, labels=['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer'], autopct='%.1f%%')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# # Exercise 20

# %%
import numpy as np
from bokeh.plotting import figure,show
import pandas as pd

df = pd.read_csv('roman-emperor-reigns.csv')

plot=figure(y_range=df['Emperor'].tolist(),title="The distribution of the Roman Emperor's reign lengths",x_axis_label="Length of Reign")
plot.hbar(y=df['Emperor'],right=df["Length_of_Reign"],left=0,height=0.5,fill_alpha=0.5)
show(plot)

# %% [markdown]
# # Exercise 21

# %%
import pandas as pd
import seaborn as sns

df= pd.read_csv('recent-college-grads-earnings.csv')
gender=[]
for i in df['ShareWomen']:
    if i<0.5:
        gender.append('Man')
    else:
        gender.append('Women')
data=pd.DataFrame({"Gender":gender,"Median":df["Median"].tolist()})

ax = sns.boxplot(x="Gender", y="Median", data=data)

# %% [markdown]
# # Exercise 22

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt  
df = pd.read_csv('us-marriages-divorces-1867-2014.csv')

plots = plt.subplots(2, sharex=True)[1]
sns.lineplot(y="Marriages_per_1000", x= "Year", data=df, ax=plots[0])
sns.lineplot(y="Divorces_per_1000", x= "Year", data=df, ax=plots[1])

# %% [markdown]
# # Exercise 23

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('percent-degrees-conferred-women-usa.csv')
plt.figure(figsize=(20, 20))
i=1
for category in df.columns[1:]:
    plt.subplot(4, 5, i)
    i+=1
    plt.plot(df['Year'],df[category])
    plt.title(category)
    
plt.tight_layout()
